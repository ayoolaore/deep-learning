# %%
pip install stability-sdk
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 23.0 MB/s  0:00:00eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 30.4 MB/s  0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.33.5
#     Uninstalling protobuf-6.33.5:
#       Successfully uninstalled protobuf-6.33.5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [stability-sdk]0m [grpcio]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ["STABILITY_KEY"] = ""
# !python -m stability_sdk generate "A stunning house."
# Out:
# 345.00s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
